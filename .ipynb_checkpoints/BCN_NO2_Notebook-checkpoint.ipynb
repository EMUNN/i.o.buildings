# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr

# %%
DS = xr.open_dataset("./barcelona_20180101-20180331_no2.nc")
DS
# Out:
# <xarray.Dataset>
# Dimensions:        (lat: 907, lon: 1008, time: 2160)
# Coordinates:
#   * lat            (lat) float32 41.291256 41.291454 ... 41.472256 41.472454
#   * lon            (lon) float32 2.057799 2.0579991 ... 2.258999 2.2591991
#   * time           (time) datetime64[ns] 2018-01-01 ... 2018-03-31T23:00:00
# Data variables:
#     isValid        (time) uint8 ...
#     no2            (time, lat, lon) float32 ...
#     numObs         (time) uint8 ...
#     precipitation  (time) float32 ...
#     temperature    (time) float32 ...
#     windU          (time) float32 ...
#     windV          (time) float32 ...
# Attributes:
#     t_calculated:  2019-11-09T00:42:36.009092
#     license:       This Lobelia Air Barcelona 2018 NO2 dataset is made availa...
#     copyright:     © Lobelia Earth & KNMI 2019
#     history:       Thu Nov 14 09:38:01 2019: ncks -d time,0,2159 barcelona_20...
#     NCO:           netCDF Operators version 4.8.1 (Homepage = http://nco.sf.n...

# %%
da = DS.no2
da
# Out:
# <xarray.DataArray 'no2' (time: 2160, lat: 907, lon: 1008)>
# [1974792960 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float32 41.291256 41.291454 41.291656 ... 41.472256 41.472454
#   * lon      (lon) float32 2.057799 2.0579991 2.0581992 ... 2.258999 2.2591991
#   * time     (time) datetime64[ns] 2018-01-01 ... 2018-03-31T23:00:00
# Attributes:
#     long_name:  NO2 concentration
#     units:      ug m-3

# %%
example = da.sel(lat=122,lon=0, method='nearest').ffill(dim='time')
example
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-33bbc776cfd2> in <module>
# ----> 1 example = da.sel(lat=122,lon=0, method='nearest').ffill(dim='time')
#       2 example
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/xarray/core/dataarray.py in ffill(self, dim, limit)
#    2158         from .missing import ffill
#    2159
# -> 2160         return ffill(self, dim, limit=limit)
#    2161
#    2162     def bfill(self, dim: Hashable, limit: int = None) -> "DataArray":
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/xarray/core/missing.py in ffill(arr, dim, limit)
#     394 def ffill(arr, dim=None, limit=None):
#     395     """forward fill missing values"""
# --> 396     import bottleneck as bn
#     397
#     398     axis = arr.get_axis_num(dim)
#
# ...
